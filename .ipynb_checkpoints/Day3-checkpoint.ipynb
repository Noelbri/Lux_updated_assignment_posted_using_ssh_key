# %% [markdown]
# ## Day 3 Assignments

# %% [markdown]
# ### List python operators
# #### 1. Arithmetic Operators
# ##### Used for mathematical operations:
#
# (+) : Addition \
# (-) : Subtraction \
# (*) : Multiplication \
# / : Division (floating-point) \
# // : Floor Division \
# % : Modulus (remainder) \
# ** : Exponentiation (power)
# #### 2. Comparison (Relational) Operators
# ##### Used to compare values:
#
# == : Equal to \
# != : Not equal to \
# (>) : Greater than \
# (<) : Less than \
# (>=) : Greater than or equal to \
# <= : Less than or equal to
# #### 3. Logical Operators
# ##### Used to perform logical operations:
#
# and : Logical AND \
# or : Logical OR \
# not : Logical NOT
# #### 4. Bitwise Operators \
# ##### Operate at the bit level:
#
# & : Bitwise AND \
# | : Bitwise OR \
# ^ : Bitwise XOR \
# ~ : Bitwise NOT \
# << : Left Shift \
# (>>) : Right Shift
# #### 5. Assignment Operators
# ##### Used to assign values to variables:
#
# = : Simple assignment \
# += : Add and assign \
# -= : Subtract and assign \
# *= : Multiply and assign \
# /= : Divide and assign \
# //= : Floor divide and assign \
# %= : Modulus and assign \
# **= : Exponentiation and assign \
# &= : Bitwise AND and assign \
# |= : Bitwise OR and assign \
# ^= : Bitwise XOR and assign \
# <<= : Left shift and assign \
# (>>=) : Right shift and assign
# #### 6. Membership Operators
# ##### Check for membership in a sequence (e.g., string, list):
#
# in : True if the value is found in the sequence \
# not in : True if the value is not found in the sequence
# #### 7. Identity Operators
# ##### Check if two objects are the same instance:
#
# is : True if the objects are the same \
# is not : True if the objects are not the same

# %%
import pyforest

# %%
import pandas as pd
df = pd.read_csv ('train_data_cross-sell.csv', encoding='latin1')
df.rename(columns = {'ÿid': 'id'}, inplace = True)
df.head()
# Out:
#           id  Gender       Customer_Date_of_Birth  Driving_License  \
# 0  549771831    Male        Monday, March 7, 1977                1
# 1  373583351    Male    Sunday, December 29, 2002                1
# 2  933163655  Female     Tuesday, August 23, 1994                1
# 3  698942186  Female  Thursday, November 18, 1999                1
# 4  515109822    Male  Thursday, February 22, 2001                1
#
#   Customer_Residence_Sub_County  Previously_Insured  \
# 0                      EMBAKASI                   0
# 1                     WESTLANDS                   1
# 2                     DAGORETTI                   1
# 3                          JUJA                   0
# 4                     WESTLANDS                   0
#
#    Vehicle_Year_of_Manufacture Vehicle_Damage  Annual_Premium      Agent_name  \
# 0                         2020            Yes           38294   Jomo Kenyatta
# 1                         2020             No           28619  Obiero Ochieng
# ...

# %%
df_sorted = df.sort_values(by='Agent_name', ascending=True)
df_sorted.head(25)
# Out:
#                id  Gender        Customer_Date_of_Birth  Driving_License  \
# 60349   347359018    Male     Saturday, January 9, 1965                1
# 86500   349931875  Female       Saturday, March 1, 1986                1
# 87013   760803848    Male       Monday, October 1, 1973                1
# 84774   576720094  Female     Monday, September 9, 1985                1
# 42123   530807088  Female     Tuesday, January 23, 1979                1
# 116897  701129581    Male      Thursday, March 30, 1978                1
# 161979  416592305  Female       Sunday, January 1, 1984                1
# 103687  286791315    Male      Friday, December 6, 1974                1
# 236346  331298792    Male  Wednesday, December 29, 1976                1
# 211202  529582442    Male     Tuesday, January 17, 1978                1
# 283717  171694862    Male       Thursday, March 1, 1979                1
# 61432   659345041  Female         Friday, April 7, 1967                1
# ...

# %%
# Step 1: Calculate performance scores (Premium and agent name)
performance_scores = df.groupby('Agent_name')['Annual_Premium'].sum().reset_index(name='performance_score')

# Step 2: Merge the performance scores back into the original DataFrame
df = df.merge(performance_scores, on='Agent_name')

performance_quartiles = df['performance_score'].quantile([0.25, 0.5, 0.75]).to_dict()
def get_performance_category(score):
    if score <= performance_quartiles[0.25]:
         return 'Low'
    elif score <= performance_quartiles[0.5]:
         return 'Medium'
    elif score <= performance_quartiles[0.75]:
         return 'High'
    else:
         return 'Top'
df['Performance_Category'] = df['performance_score'].apply(get_performance_category)
df.head()
# Out:
#           id  Gender       Customer_Date_of_Birth  Driving_License  \
# 0  549771831    Male        Monday, March 7, 1977                1
# 1  373583351    Male    Sunday, December 29, 2002                1
# 2  933163655  Female     Tuesday, August 23, 1994                1
# 3  698942186  Female  Thursday, November 18, 1999                1
# 4  515109822    Male  Thursday, February 22, 2001                1
#
#   Customer_Residence_Sub_County  Previously_Insured  \
# 0                      EMBAKASI                   0
# 1                     WESTLANDS                   1
# 2                     DAGORETTI                   1
# 3                          JUJA                   0
# 4                     WESTLANDS                   0
#
#    Vehicle_Year_of_Manufacture Vehicle_Damage  Annual_Premium      Agent_name  \
# 0                         2020            Yes           38294   Jomo Kenyatta
# 1                         2020             No           28619  Obiero Ochieng
# ...

# %%
df['Performance_Category'].value_counts()
# Out:
# Performance_Category
# Low       142008
# High      114607
# Medium     67851
# Name: count, dtype: int64

# %%
class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year

    def display_car_info(self):
        print(f"Your car make is {self.make}, the model is {self.model}, and the year of release is {self.year}")


car_list = []

while True:
    print("\nEnter car details:")
    make = input("Enter the make of your car: ")
    model = input("Enter the model of your car: ")
    year = input("Enter the year of your car: ")

    car1 = Car(make, model, year)  # Use the class name with capitalized "Car"
    car_list.append(car1)  # Append the object (car1), not the class (Car)

    another = input("Do you want to enter another car? (yes/no): ").strip().lower()
    if another != "yes":
        break

print("\nCar Information Entered:")
for i, car in enumerate(car_list, start=1):  # No variable name conflicts now
    print(f"\nCar {i}:")
    car.display_car_info()
# Out:
# Enter car details:
# Enter the make of your car:  toyota
# Enter the model of your car:  corolla
# Enter the year of your car:  2021
# Do you want to enter another car? (yes/no):  yes
# Enter car details:
# Enter the make of your car:  honda
# Enter the model of your car:  civic
# Enter the year of your car:  2021
# Do you want to enter another car? (yes/no):  no
# Car Information Entered:
#
# Car 1:
# Your car make is toyota, the model is corolla, and the year of release is 2021
#
# Car 2:
# Your car make is honda, the model is civic, and the year of release is 2021
